# %%
library(repr)
library(tidyverse)

library(tidymodels)
library(gridExtra)
options(repr.matrix.max.rows = 10)

# %% [markdown]
# # Classification

# %% [markdown]
# * We have to change the claim to something like this:
#
#  *We can predict wether or not an individual is signed up to recieve news letter by using their age and experience level.*
#
#  We do this by knn classification model and furthermore use our tools to check the accuracy (or precision) of the model that we built.

# %%
players_data<-read_csv("https://raw.githubusercontent.com/lilypurdy/toy_ds_project/refs/heads/main/players%20(2).csv")
head(players_data, 5)
# Out:
# Rows: 196 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, Age
# lgl (1): subscribe
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   experience subscribe
# 1 Pro         TRUE
# 2 Veteran     TRUE
# 3 Veteran    FALSE
# 4 Amateur     TRUE
# 5 Regular     TRUE
#   hashedEmail                                                      played_hours
# 1 f6daba428a5e19a3d47574858c13550499be23603422e6a0ee9728f8b53e192d 30.3
# 2 f3c813577c458ba0dfef80996f8f32c93b6e8af1fa939732842f2312358a88e9  3.8
# 3 b674dd7ee0d24096d1c019615ce4d12b20fcbff12d79d3c5a9d2118eb7ccbb28  0.0
# 4 23fe711e0e3b77f1da7aa221ab1192afe21648d47d2b4fa7a5a659ff443a0eb5  0.7
# 5 7dc01f10bf20671ecfccdac23812b1b415acd42c2147cb0af4d48fcce2420f3e  0.1
#   name      gender Age
# 1 Morgan    Male    9
# 2 Christian Male   17
# 3 Blake     Male   17
# 4 Flora     Female 21
# 5 Kylie     Male   21

# %%
clean_players_data <- read_csv("https://raw.githubusercontent.com/Jamesnam1/toy_ds_project/refs/heads/main/players.csv",
    col_names = c("experience", "subscribed", "hashed_email", "hours_played", "name", "gender", "age"),
                col_types = list("c", "l", "c", "d", "c", "c", "i"))
clean_players_data
# Out:
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
#     experience subscribed
# 1   experience    NA
# 2   Pro         TRUE
# 3   Veteran     TRUE
# 4   Veteran    FALSE
# 5   Amateur     TRUE
# ⋮   ⋮          ⋮
# 193 Amateur     TRUE
# 194 Veteran    FALSE
# 195 Amateur    FALSE
# 196 Amateur    FALSE
# 197 Pro         TRUE
#     hashed_email
# 1   hashedEmail
# 2   f6daba428a5e19a3d47574858c13550499be23603422e6a0ee9728f8b53e192d
# 3   f3c813577c458ba0dfef80996f8f32c93b6e8af1fa939732842f2312358a88e9
# 4   b674dd7ee0d24096d1c019615ce4d12b20fcbff12d79d3c5a9d2118eb7ccbb28
# 5   23fe711e0e3b77f1da7aa221ab1192afe21648d47d2b4fa7a5a659ff443a0eb5
# ⋮   ⋮
# 193 b6e9e593b9ec51c5e335457341c324c34a2239531e1890b93ca52ac1dc76b08f
# 194 71453e425f07d10da4fa2b349c83e73ccdf0fb3312f778b35c5802c3292c87bd
# 195 d572f391d452b76ea2d7e5e53a3d38bfd7499c7399db299bd4fedb06a46ad5bb
# 196 f19e136ddde68f365afc860c725ccff54307dedd13968e896a9f890c40aea436
# 197 d9473710057f7d42f36570f0be83817a4eea614029ff90cf50d8889cdd729d11
#     hours_played name      gender            age
# 1     NA         name      gender            NA
# 2   30.3         Morgan    Male               9
# 3    3.8         Christian Male              17
# 4    0.0         Blake     Male              17
# 5    0.7         Flora     Female            21
# ⋮   ⋮            ⋮         ⋮                 ⋮
# 193 0.0          Bailey    Female            17
# 194 0.3          Pascal    Male              22
# 195 0.0          Dylan     Prefer not to say 17
# 196 2.3          Harlow    Male              17
# 197 0.2          Ahmed     Other             NA

# %%
clean_players_data |>
  distinct(experience)
# Out:
#   experience
# 1 experience
# 2 Pro
# 3 Veteran
# 4 Amateur
# 5 Regular
# 6 Beginner

# %%
players <- clean_players_data |>
  select(-hashed_email, -subscribed, -name, -gender) |>
  filter(!is.na(age)) |>
  mutate(
    experience = case_when(
      experience == "Pro" ~ 5,
      experience == "Veteran" ~ 4,
      experience == "Amateur" ~ 3,
      experience == "Regular" ~ 2,
      experience == "Beginner" ~ 1,
      TRUE ~ NA_real_
    ), 
   level = case_when(
      hours_played > 40 ~ "high",
      hours_played <= 40 ~ "low"))|>
    arrange(-hours_played)
players
# Out:
#     experience hours_played age level
# 1   2          223.1        17  high
# 2   2          218.1        20  high
# 3   2          178.2        19  high
# 4   3          150.0        16  high
# 5   3           56.1        23  high
# ⋮   ⋮          ⋮            ⋮   ⋮
# 190 1          0            17  low
# 191 3          0            17  low
# 192 3          0            20  low
# 193 3          0            17  low
# 194 3          0            17  low

# %%
players <- select(players, -hours_played)|>
    mutate(level = as_factor(level))
players
# Out:
#     experience age level
# 1   2          17  high
# 2   2          20  high
# 3   2          19  high
# 4   3          16  high
# 5   3          23  high
# ⋮   ⋮          ⋮   ⋮
# 190 1          17  low
# 191 3          17  low
# 192 3          20  low
# 193 3          17  low
# 194 3          17  low

# %%
initial_scatter <- players |>
  ggplot(aes(x = age, y = experience, color = level)) +
  geom_point(alpha = 0.6) +
  labs(x = "Perimeter (standardized)",
       y = "Concavity (standardized)",
       color = "Diagnosis") +
  scale_color_manual(values = c("darkorange", "steelblue")) +
  theme(text = element_text(size = 12))
initial_scatter
# Out:
# plot without title

# %%
set.seed(1)

split_data <- initial_split(players, prop = 3/4, strata = level)

training_data <- training(split_data)
testing_data <- testing(split_data)

head(training_data)
# Out:
#   experience age level
# 1 2          17  high
# 2 2          20  high
# 3 3          17  high
# 4 1          24  low
# 5 4          27  low
# 6 1          17  low

# %%
set.seed(1)
knn_spec <- nearest_neighbor(weight_func = "rectangular", neighbors = 30) |>
  set_engine("kknn") |>
  set_mode("classification")

# %%
set.seed(1)
player_split <- initial_split(training_data, prop = 0.75, strata = level)
player_subtrain <- training(player_split)
player_validation <- testing(player_split)
head(player_subtrain)
# Out:
#   experience age level
# 1 2          17  high
# 2 2          20  high
# 3 1          17  low
# 4 2          17  low
# 5 3          21  low
# 6 4          22  low

# %%
set.seed(1)
player_recipe <- recipe(level ~ age + experience,
                        data = player_subtrain) |>
  step_scale(all_predictors()) |>
  step_center(all_predictors())

knn_fit <- workflow() |>
  add_recipe(player_recipe) |>
  add_model(knn_spec) |>
  fit(data = player_subtrain)

validation_predicted <- predict(knn_fit, player_validation) |>
  bind_cols(player_validation)

acc <- validation_predicted |>
  metrics(truth = level, estimate = .pred_class) |>
  filter(.metric == "accuracy") |>
  select(.estimate) |>
  pull()

acc
# Out:
# [1] 0.972973

# %%
set.seed(1)
player_vfold <- vfold_cv(training_data, v = 10, strata = level)

# %%
set.seed(1)

player_recipe <- recipe(level ~ age + experience,
                        data = training_data) |>
  step_scale(all_predictors()) |>
  step_center(all_predictors())

knn_fit <- workflow() |>
  add_recipe(player_recipe) |>
  add_model(knn_spec) |>
  fit_resamples(resamples = player_vfold) |>
    collect_metrics()

knn_fit
# Out:
# → A | warning: No event observations were detected in `truth` with event level 'high'.
#
# There were issues with some computations   A: x1
#
# There were issues with some computations   A: x3
#
# There were issues with some computations   A: x7
#   .metric  .estimator mean      n  std_err    .config
# 1 accuracy binary     0.9795238 10 0.01043402 Preprocessor1_Model1
# 2 roc_auc  binary     0.6025641  3 0.16070320 Preprocessor1_Model1

# %%
set.seed(1)
knn_spec <- nearest_neighbor(weight_func = "rectangular",
                             neighbors = tune()) |>
  set_engine("kknn") |>
  set_mode("classification")

# %%
k_vals <- tibble(neighbors = seq(from = 1, to = 100, by = 5))

knn_results <- workflow() |>
  add_recipe(player_recipe) |>
  add_model(knn_spec) |>
  tune_grid(resamples = player_vfold, grid = k_vals) |>
  collect_metrics()

accuracies <- knn_results |>
  filter(.metric == "accuracy")

accuracies
# Out:
# → A | warning: No event observations were detected in `truth` with event level 'high'.
#
# There were issues with some computations   A: x3
#
# There were issues with some computations   A: x6
#
# There were issues with some computations   A: x7
#    neighbors .metric  .estimator mean      n  std_err    .config
# 1   1        accuracy binary     0.8223810 10 0.03015915 Preprocessor1_Model01
# 2   6        accuracy binary     0.9795238 10 0.01043402 Preprocessor1_Model02
# 3  11        accuracy binary     0.9795238 10 0.01043402 Preprocessor1_Model03
# 4  16        accuracy binary     0.9795238 10 0.01043402 Preprocessor1_Model04
# 5  21        accuracy binary     0.9795238 10 0.01043402 Preprocessor1_Model05
# ⋮  ⋮         ⋮        ⋮          ⋮         ⋮  ⋮          ⋮
# 16 76        accuracy binary     0.9795238 10 0.01043402 Preprocessor1_Model16
# 17 81        accuracy binary     0.9795238 10 0.01043402 Preprocessor1_Model17
# 18 86        accuracy binary     0.9795238 10 0.01043402 Preprocessor1_Model18
# 19 91        accuracy binary     0.9795238 10 0.01043402 Preprocessor1_Model19
# 20 96        accuracy binary     0.9795238 10 0.01043402 Preprocessor1_Model20

# %%
accuracy_vs_k <- ggplot(accuracies, aes(x = neighbors, y = mean)) +
  geom_point() +
  geom_line() +
  labs(x = "Neighbors", y = "Accuracy Estimate") +
  theme(text = element_text(size = 12))

accuracy_vs_k
# Out:
# plot without title

# %%
set.seed(1)

Wdbc_recipe <- recipe(level ~ age + experience, data = players) |>                     
  step_center(all_predictors()) |>  
  step_scale(all_predictors())     

Wdbc_model <- nearest_neighbor(weight_func = "rectangular", neighbors = 3) |>
  set_engine("kknn") |>
  set_mode("classification")

Wdbc_workflow <- workflow() |>
  add_recipe(Wdbc_recipe) |>
  add_model(Wdbc_model)

Wdbc_fit <- Wdbc_workflow |>
  fit(data = players)

new_obs <- tibble(age = 18, experience = 4)  
predict(Wdbc_fit, new_obs)
# Out:
#   .pred_class
# 1 low
